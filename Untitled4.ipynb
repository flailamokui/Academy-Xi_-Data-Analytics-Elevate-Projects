# %% [markdown]
# <a href="https://colab.research.google.com/github/flailamokui/Academy-Xi_-Data-Analytics-Elevate-Projects/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/diabetes.csv')
display(df.head())
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
# Analyze the balance of 'class' variable
print("Class Distribution:")
display(df['class'].value_counts())
# Out:
# Class Distribution:
# class
# tested_negative    500
# tested_positive    268
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='class', palette='viridis')
plt.title('Distribution of Diabetes Classes')
plt.xlabel('Diabetes Class')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipykernel_5629/1584874655.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='class', palette='viridis')
